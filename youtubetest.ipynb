# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
def api_connect():
    api_id='AIzaSyAx4iihyg9JpRI1hWMFJZozN3aFfQuFTPM'
    api_service_name="youtube"
    api_version="v3"
    youtube=build(api_service_name,api_version,developerKey= api_id)
    return youtube
youtube=api_connect()

# %%
# get channels information
def get_channel_info(c_id):

    request = youtube.channels().list(
            part="snippet,contentDetails,statistics",
            id=c_id
        )
    response = request.execute()
    for i in response['items']:
        data=dict(channel_Name=i[ 'snippet']['title'],
                channel_id=i["id"],
                subsribers=i['statistics']['subscriberCount'],
                views=i['statistics']['viewCount'],
                Total_Videos=i['statistics']['videoCount'],
                Channel_Description=i['snippet']['description'],
                Playlist_ID=i['contentDetails']['relatedPlaylists']['uploads']
        )
    return data

# %%
channel_details=get_channel_info("UCunaYVFwuXJj2Dg3ekXqlBQ")

# %%
channel_details
# Out:
# {'channel_Name': 'Gudiyattam 360',
#  'channel_id': 'UCunaYVFwuXJj2Dg3ekXqlBQ',
#  'subsribers': '42000',
#  'views': '5210627',
#  'Total_Videos': '93',
#  'Channel_Description': 'Welcome To GUDIYATTAM360\n\nEntertainment and social content. \nDont Forgot to subscribe us. \nClick The Bell icon for instant updates. \n\nfollow us on Facebook,Instagram.\n\nFor promotions and Advertisement please contact to \n\nmail id - gudiyatham360@gmail.com\ncontact - 877 833 8770\n',
#  'Playlist_ID': 'UUunaYVFwuXJj2Dg3ekXqlBQ'}

# %%
# get video ids
def get_video_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    Playlist_ID=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None
    while True:
        response1=youtube.playlistItems().list(
            part='snippet',
            playlistId=Playlist_ID,
            maxResults=50,
            pageToken=next_page_token
            ).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')

        if next_page_token is None:
            break
    return video_ids

# %%
Video_id=get_video_ids('UCEMquPOusz7h58nimU7P0uA')

# %%
len(Video_id)
# Out:
# 258

# %%
# to get video information
def get_video_details(v_i):
    video_data=[]
    for video_id in v_i:
        request=youtube.videos().list(
            part='snippet,ContentDetails,statistics',
            id=video_id
        )
        response=request.execute()
        for item in response['items']:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumbnail=item['snippet']['thumbnails']['default']['url'],
                    Description=item['snippet'].get('description'),
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item['statistics'].get('viewCount'),
                    Likes=item['statistics'].get('likeCount'),
                    Comments=item['statistics'].get('commentCount'),
                    Favourite_Count=item['statistics']['favoriteCount'],
                    Definition=item['contentDetails']['definition'],
                    Caption_Details=item['contentDetails']['caption']
                    )
            video_data.append(data)
    return video_data

# %%
video_details=get_video_details(Video_id)

# %%
video_details
# Out:
# [{'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'iwhqavkYCfo',
#   'Title': 'Very easy Background decoration idea!! | craftsea',
#   'Tags': ['craftsea',
#    'easy background decoration ideas',
#    'background decoration ideas',
#    'decoration ideas',
#    'background',
#    'easy decoration ideas',
#    'pooja decoration ideas',
#    'pooja decoration',
#    'easy decoration',
#    'diy decor',
#    'pooja decoration ideas at home'],
#   'Thumbnail': 'https://i.ytimg.com/vi/iwhqavkYCfo/default.jpg',
#   'Description': 'This video is about background decoration ideas for festival at home \n#backgrounddecoration #decorationideas #craftsea',
#   'Published_Date': '2024-01-18T10:30:13Z',
#   'Duration': 'PT5M32S',
#   'Views': '139',
#   'Likes': '13',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '_xj9f2rsUks',
#   'Title': 'DIY paper pulp rangoli | CRAFTSEA',
#   'Tags': ['craftsea',
#    'paper rangoli',
#    'paper pulp rangoli',
#    'diy paper rangoli',
#    'easy rangoli ideas',
#    'easy rangoli',
#    'rangoli',
#    'paper recycling',
#    'paper crafts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_xj9f2rsUks/default.jpg',
#   'Description': '#paperrangoli #rangoli #papercraft',
#   'Published_Date': '2023-12-28T12:30:30Z',
#   'Duration': 'PT2M51S',
#   'Views': '145',
#   'Likes': '15',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '4zmeVTTARqE',
#   'Title': '#shorts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/4zmeVTTARqE/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-27T15:03:15Z',
#   'Duration': 'PT11S',
#   'Views': '2539',
#   'Likes': '51',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'iW_IOdXrIdQ',
#   'Title': 'Amazing diy garland #shorts #garland #garlandmaking #trending #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/iW_IOdXrIdQ/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-26T07:33:52Z',
#   'Duration': 'PT13S',
#   'Views': '648',
#   'Likes': '25',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'sASDbpT_ioQ',
#   'Title': 'Pooja decoration ideas 💡 #shorts #poojadecoration #poojadecorationideas #decorationideas #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/sASDbpT_ioQ/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-25T15:31:50Z',
#   'Duration': 'PT11S',
#   'Views': '300',
#   'Likes': '29',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'nogKOjsYaTQ',
#   'Title': 'Wall decor #shorts #walldecor #trending #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/nogKOjsYaTQ/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-24T10:03:47Z',
#   'Duration': 'PT15S',
#   'Views': '597',
#   'Likes': '17',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'sChY0gCBQBY',
#   'Title': 'DIY Kundan Venkateshwara decoration | Wall decoration ideas | Kundan decoration idea CRAFTSEA',
#   'Tags': ['DIY kundan wall decoration idea',
#    'kundan rangoli',
#    'wall decoration ideas',
#    'kundan decoration idea',
#    'kundan rangoli venkateswara',
#    'kundan work craft',
#    'kundan craft',
#    'wall hanging ideas',
#    'wall decor',
#    'kundan rangoli designs',
#    'kundan wall art',
#    'kundan art on ohb sheet',
#    'kundan wall hanging designs',
#    'kundan rangoli designes ideas at home',
#    'kundan decoration ideas',
#    'venkateswara wall art',
#    'craftsea',
#    'govinda',
#    'govinda painting',
#    'krishna'],
#   'Thumbnail': 'https://i.ytimg.com/vi/sChY0gCBQBY/default.jpg',
#   'Description': 'This video is about decorating wall using kundan and painting. Kundan wall decoration idea rangoli | diy kundan decoration idea | Venkateshwara decoration idea on wall | \n#kundanrangoli #walldecorationideas #walldecor #craftsea #kundanwork',
#   'Published_Date': '2023-12-23T12:30:38Z',
#   'Duration': 'PT10M2S',
#   'Views': '151',
#   'Likes': '16',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '9R3X2x7xD1Y',
#   'Title': 'Vaikunta Ekadasi special 🙏 #shorts  #govinda #srikrishnagovinda #vaikundaekadesi',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/9R3X2x7xD1Y/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-23T09:59:08Z',
#   'Duration': 'PT17S',
#   'Views': '295',
#   'Likes': '37',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'NwHc6AdWZDA',
#   'Title': 'Trendy new design Garland | Cloth garland | garland using fabric diy | CRAFTSEA',
#   'Tags': ['craftsea',
#    'garland making',
#    'garland',
#    'trendy garland',
#    'easy garland',
#    'cloth garland',
#    'garland using cloth',
#    'fabric garland',
#    'garland using fabric',
#    'how to make garland',
#    'how to make garland using cloth',
#    'garland making with cloth',
#    'cloth garland making',
#    'fabric garland making',
#    'pooja decoration ideas',
#    'fabric toran'],
#   'Thumbnail': 'https://i.ytimg.com/vi/NwHc6AdWZDA/default.jpg',
#   'Description': 'This video is about how to make a garland using cloth with detailed measurement details \n\n#garland #garlandmaking #clothgarland #craftsea \n#poojadecoration',
#   'Published_Date': '2023-12-22T12:30:13Z',
#   'Duration': 'PT7M46S',
#   'Views': '284',
#   'Likes': '24',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '7tZvWVEpzXY',
#   'Title': 'Vaikunta ekadasi special ✨ #shorts #decorationideas',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/7tZvWVEpzXY/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-22T09:30:04Z',
#   'Duration': 'PT14S',
#   'Views': '935',
#   'Likes': '29',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'hnib76jts1k',
#   'Title': 'Thoranam decoration ideas #shorts #thoranam #thoran #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/hnib76jts1k/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-21T09:30:19Z',
#   'Duration': 'PT18S',
#   'Views': '1313',
#   'Likes': '27',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '2Du2AgTcUpI',
#   'Title': 'Fantastic IDEA! Thoran using satin ribbon ?? | Toranam making | CRAFTSEA',
#   'Tags': ['satin ribbon',
#    'satin ribbon thoran',
#    'thoran',
#    'easy',
#    'fantastic idea',
#    'craftsea',
#    'thoranam',
#    'how to do thoranam',
#    'artificial thoranam',
#    'thoranam decoration ideas',
#    'thoranam decoration'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2Du2AgTcUpI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-20T12:30:01Z',
#   'Duration': 'PT2M50S',
#   'Views': '126',
#   'Likes': '19',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '3MNpMDUGDgs',
#   'Title': 'Home decoration ideas 💡 #shorts #decorationideas #homedecor #viral #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/3MNpMDUGDgs/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-20T10:11:41Z',
#   'Duration': 'PT11S',
#   'Views': '2386',
#   'Likes': '50',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'Q3PRCZ4tHpo',
#   'Title': 'Garland making #shorts #garland #garlandmaking #craftsea #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Q3PRCZ4tHpo/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T12:30:15Z',
#   'Duration': 'PT13S',
#   'Views': '1585',
#   'Likes': '45',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'rLGcVt2Kdsk',
#   'Title': 'How to do lippan art at HOME | Lippan art | mirror art | CRAFTSEA',
#   'Tags': ['lippan art',
#    'how to do lippan art',
#    'how to',
#    'lippan art at home',
#    'at home',
#    'lippan',
#    'craftsea'],
#   'Thumbnail': 'https://i.ytimg.com/vi/rLGcVt2Kdsk/default.jpg',
#   'Description': 'This video is about making lippan art at home easily | craftsea',
#   'Published_Date': '2023-12-15T12:30:36Z',
#   'Duration': 'PT9M36S',
#   'Views': '218',
#   'Likes': '18',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'oxs4VdaXBLI',
#   'Title': 'Wall hanging idea #shorts  #decorationideas #wallhanging',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/oxs4VdaXBLI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-14T10:23:13Z',
#   'Duration': 'PT20S',
#   'Views': '297',
#   'Likes': '24',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'xlb9-fz1o7U',
#   'Title': 'Door magnets #shorts #diy #clayart',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/xlb9-fz1o7U/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-12T12:30:28Z',
#   'Duration': 'PT15S',
#   'Views': '2585',
#   'Likes': '70',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'vTg1D5tdvZ4',
#   'Title': 'Wow idea with Paint bottle #shorts #clayart #clay #trending #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/vTg1D5tdvZ4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-10T22:30:04Z',
#   'Duration': 'PT12S',
#   'Views': '2838',
#   'Likes': '63',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'U2jb7ArwlT4',
#   'Title': 'Ganesha 3D clay mural painting Part-2 #craftsea #clayart #claymodelling',
#   'Tags': ['craftsea',
#    'ganesha clay mural art',
#    'ganesha clay mural painting',
#    'clay art',
#    'clay ganesha',
#    'canvas painting ganesha',
#    'clay painting',
#    'clay mural art on canvas',
#    '3d wall hanging craft ideas',
#    'ganesha painting',
#    'clay painting on canvas',
#    '3d painting',
#    'mural clay art',
#    'mural art painting',
#    '3d clay painting',
#    'ganpati mural painting',
#    '3D WALL DECOR',
#    'part-2'],
#   'Thumbnail': 'https://i.ytimg.com/vi/U2jb7ArwlT4/default.jpg',
#   'Description': 'This video is about how to make a 3D Ganesha Clay Wall Hanging easily | EASY Ganpati Clay Mural Painting | #clayart #muralart | CRAFTSEA \nPART-2 | 3D WALL DECOR\n\nganesha clay mural art,ganesha clay mural painting,clay art,clay ganesha,canvas painting ganesha,clay painting,clay mural art on canvas,3d wall hanging craft ideas,ganesha painting,clay painting on canvas,3d painting,mural clay art,mural art painting,3d clay painting,ganesha clay mural art, ganesha clay mural painting, ganpati mural painting, ganesha clay mural art, ganesha clay mural painting, clay art\n3d wall decor',
#   'Published_Date': '2023-12-09T12:30:14Z',
#   'Duration': 'PT15M30S',
#   'Views': '369',
#   'Likes': '16',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'OpZPSD3fL6o',
#   'Title': 'Clay art #shorts #clayart #tulasi #viral #trending #craftsea',
#   'Tags': ['shorts',
#    'clay art',
#    'clay',
#    'art',
#    'shorts feed',
#    'viral',
#    'trending',
#    'craftsea'],
#   'Thumbnail': 'https://i.ytimg.com/vi/OpZPSD3fL6o/default.jpg',
#   'Description': 'Clay art / #shorts #clayart #clay #mouldit #craftsea #tulasi',
#   'Published_Date': '2023-12-09T08:32:42Z',
#   'Duration': 'PT20S',
#   'Views': '2717',
#   'Likes': '64',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'z6oZPg6vn1w',
#   'Title': 'Ganesha 3D clay mural painting #shorts #ganesha #clayart',
#   'Tags': ['shorts', 'shortsfeed', 'viral', 'trending', 'ganesha', 'clay art'],
#   'Thumbnail': 'https://i.ytimg.com/vi/z6oZPg6vn1w/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-08T04:44:08Z',
#   'Duration': 'PT13S',
#   'Views': '949',
#   'Likes': '102',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '42uUbfoZj8Q',
#   'Title': '3D Ganesha Clay Wall Hanging PART-1 | EASY Ganpati Clay Mural Painting | #clayart #muralart',
#   'Tags': ['craftsea',
#    'PART-1',
#    'ganesha clay mural art',
#    'ganesha clay mural painting',
#    'clay art',
#    'clay ganesha',
#    'canvas painting ganesha',
#    'clay painting',
#    'clay mural art on canvas',
#    '3d wall hanging craft ideas',
#    'ganesha painting',
#    'clay painting on canvas',
#    '3d painting',
#    'mural clay art',
#    'mural art painting',
#    '3d clay painting',
#    'ganpati mural painting',
#    '3D WALL DECOR'],
#   'Thumbnail': 'https://i.ytimg.com/vi/42uUbfoZj8Q/default.jpg',
#   'Description': 'This video is about how to make a 3D Ganesha Clay Wall Hanging easily | EASY Ganpati Clay Mural Painting | #clayart #muralart | CRAFTSEA \nPART-1 | 3D WALL DECOR\n\nganesha clay mural art,ganesha clay mural painting,clay art,clay ganesha,canvas painting ganesha,clay painting,clay mural art on canvas,3d wall hanging craft ideas,ganesha painting,clay painting on canvas,3d painting,mural clay art,mural art painting,3d clay painting,ganesha clay mural art, ganesha clay mural painting, ganpati mural painting, ganesha clay mural art, ganesha clay mural painting, clay art\n3d wall decor',
#   'Published_Date': '2023-12-07T12:30:02Z',
#   'Duration': 'PT11M34S',
#   'Views': '211',
#   'Likes': '27',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'd1B_p4ceetg',
#   'Title': 'Clay modelling #clayart #shorts #trending #claymodelling #trending #shortsvideo',
#   'Tags': ['shorts',
#    'clay art',
#    'clay modelling',
#    'mural ganesha',
#    'mural art',
#    'ganesha making',
#    'shorts video',
#    'trending',
#    'viral',
#    'ganesha',
#    'Ganapathi',
#    'Ganapathi bappa',
#    'bappa',
#    '2023'],
#   'Thumbnail': 'https://i.ytimg.com/vi/d1B_p4ceetg/default.jpg',
#   'Description': '#shorts #viral #ganesha',
#   'Published_Date': '2023-12-07T08:06:04Z',
#   'Duration': 'PT13S',
#   'Views': '2460',
#   'Likes': '98',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'dq9h0LuCAjw',
#   'Title': 'pookolam #shorts #pookolam',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/dq9h0LuCAjw/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-27T13:56:02Z',
#   'Duration': 'PT24S',
#   'Views': '631',
#   'Likes': '40',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'fvBfmayvX0k',
#   'Title': 'Pookolam #shorts #pookolam',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fvBfmayvX0k/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-26T14:51:23Z',
#   'Duration': 'PT19S',
#   'Views': '736',
#   'Likes': '27',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'JJIg_josejU',
#   'Title': 'Karthigai deepam #shorts #karthigaideepam #viral #trending #karthigaideepamkolam',
#   'Tags': ['shorts', 'Diwali decoration ideas', 'Diwali', 'Diwali decoration'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JJIg_josejU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-30T05:10:47Z',
#   'Duration': 'PT53S',
#   'Views': '2471',
#   'Likes': '117',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '1ILXWIXH9i0',
#   'Title': 'paper crafts #shorts #craftsea #trending #viral #papercraft #diy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1ILXWIXH9i0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-28T12:30:00Z',
#   'Duration': 'PT15S',
#   'Views': '4363',
#   'Likes': '111',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'ab75NaIn7_k',
#   'Title': 'tissue paper crafts #craftsea #shorts #viral #trending #papercraft #diy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ab75NaIn7_k/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-27T12:30:00Z',
#   'Duration': 'PT16S',
#   'Views': '3863',
#   'Likes': '73',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'WognNRMd09I',
#   'Title': 'paper butterfly making #craftsea #shortsvideo #shorts #viral #papercraft #diy #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/WognNRMd09I/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-26T14:03:04Z',
#   'Duration': 'PT14S',
#   'Views': '2617',
#   'Likes': '93',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'W_42TPzB2Yc',
#   'Title': 'paper crafts #shorts #trending #craftsea #papercraft #diy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/W_42TPzB2Yc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-24T12:49:24Z',
#   'Duration': 'PT15S',
#   'Views': '2335',
#   'Likes': '73',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'L2yvTgTmBA0',
#   'Title': 'Trending #shorts #trending #craftsea',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/L2yvTgTmBA0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-19T13:27:59Z',
#   'Duration': 'PT14S',
#   'Views': '640',
#   'Likes': '42',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'p3MPJvv5nRk',
#   'Title': '#shorts #craftsea #ipl #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/p3MPJvv5nRk/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-18T16:00:09Z',
#   'Duration': 'PT16S',
#   'Views': '2396',
#   'Likes': '66',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '7uvc0OaeGvk',
#   'Title': 'peacock making using foam sheet #shorts #diycrafts #craftsea #peacock #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/7uvc0OaeGvk/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-15T12:30:04Z',
#   'Duration': 'PT16S',
#   'Views': '3914',
#   'Likes': '93',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'vt1rSXB3Vcg',
#   'Title': '#shorts #papercraft #craftsea #trending #papercrafts #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/vt1rSXB3Vcg/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-15T03:56:05Z',
#   'Duration': 'PT18S',
#   'Views': '1941',
#   'Likes': '54',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'abjvEtDcRPA',
#   'Title': 'Envelope making with paper | paper crafts #shorts #papercraft #craftsea #envelope',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/abjvEtDcRPA/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-13T12:30:02Z',
#   'Duration': 'PT13S',
#   'Views': '2221',
#   'Likes': '74',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '1KJQXmXHnZI',
#   'Title': 'Paper crafts #shorts #papercraft #craftsea #papercrafts #bow #diy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1KJQXmXHnZI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-12T12:30:00Z',
#   'Duration': 'PT30S',
#   'Views': '1496',
#   'Likes': '67',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'VbvaoTXuhoU',
#   'Title': '#shorts #greengreengrass #tiktok',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/VbvaoTXuhoU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-10T14:58:24Z',
#   'Duration': 'PT14S',
#   'Views': '1601',
#   'Likes': '45',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '1HYqS9hmiqE',
#   'Title': 'Mini bottle art #shorts #craftsea #bottleart #trending #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1HYqS9hmiqE/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-09T14:13:27Z',
#   'Duration': 'PT16S',
#   'Views': '2488',
#   'Likes': '54',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'agTF1z92zqg',
#   'Title': 'Mini bottle art #shorts #minibottleart #craftsea #bottleart #viral #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/agTF1z92zqg/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-08T12:30:01Z',
#   'Duration': 'PT20S',
#   'Views': '3965',
#   'Likes': '69',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'lYT3XVUwwmk',
#   'Title': 'Satin ribbon flower garland making | craftsea #satinribbon',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/lYT3XVUwwmk/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-07T12:30:20Z',
#   'Duration': 'PT5M24S',
#   'Views': '421',
#   'Likes': '22',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'OqWzlWvLy0o',
#   'Title': 'mini bottle art #shorts #craftsea #minibottleart #bottleart #diy #viral #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/OqWzlWvLy0o/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-07T12:30:11Z',
#   'Duration': 'PT13S',
#   'Views': '2132',
#   'Likes': '61',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'biI7NDvy2iU',
#   'Title': 'Paper butterfly making diy #shorts #craftsea #papercraft #paperbutterflies #butterfly #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/biI7NDvy2iU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-06T12:30:16Z',
#   'Duration': 'PT16S',
#   'Views': '1947',
#   'Likes': '85',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'kIOjng2dZUI',
#   'Title': 'Paper toy.  #shorts #papercraft #craftsea #paperfolding #diy #viral #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/kIOjng2dZUI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-05T12:30:32Z',
#   'Duration': 'PT24S',
#   'Views': '2004',
#   'Likes': '73',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '6FF-I77hwa8',
#   'Title': 'Paper flower making #shorts #paperflower #craftsea #diy #trending #papercrafts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/6FF-I77hwa8/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-04T12:30:02Z',
#   'Duration': 'PT15S',
#   'Views': '2687',
#   'Likes': '70',
#   'Comments': '3',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'KTQPWvsFsPg',
#   'Title': '#shorts #papercraft #craftsea #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/KTQPWvsFsPg/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-03T14:37:57Z',
#   'Duration': 'PT16S',
#   'Views': '2055',
#   'Likes': '65',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'I_Ay1CEsCgc',
#   'Title': 'Paper crafts #shorts #papercraft',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/I_Ay1CEsCgc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-01T12:54:09Z',
#   'Duration': 'PT15S',
#   'Views': '899',
#   'Likes': '39',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'ukAluUoWkcE',
#   'Title': '#shorts #waterdiya #trending #diya #craftsea',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ukAluUoWkcE/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-30T13:58:38Z',
#   'Duration': 'PT12S',
#   'Views': '1790',
#   'Likes': '55',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'I4lDDZsMJow',
#   'Title': 'Satin ribbon flower garland making | How to do garland at home |  craftsea #satinribbon',
#   'Tags': ['Garland making',
#    'satin ribbon garland making',
#    'garland making with satin ribbon',
#    'garland making using satin ribbon',
#    'using satin ribbon garland making',
#    'satin ribbon garland',
#    'diy satin ribbon garland',
#    'satin ribbon garland for god',
#    'satin ribbon rose garland',
#    'satin ribbon',
#    'garland',
#    'satin ribbon flower garland',
#    'artificial garland'],
#   'Thumbnail': 'https://i.ytimg.com/vi/I4lDDZsMJow/default.jpg',
#   'Description': 'How to do garland at home using satin ribbon        \n\n    #garlandmaking   \n\n  #garland #satinribbon #craftsea #satinribbongarland #flowergarland',
#   'Published_Date': '2023-03-30T12:30:09Z',
#   'Duration': 'PT6M2S',
#   'Views': '448',
#   'Likes': '27',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'HJ4MXKVIAfU',
#   'Title': 'Paper flower #shorts #paperflower #craftsea #trending #diy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/HJ4MXKVIAfU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-29T13:11:12Z',
#   'Duration': 'PT15S',
#   'Views': '1750',
#   'Likes': '58',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'ifYOwgdH5ro',
#   'Title': 'paper flower #shorts #craftsea #paperflower #trending #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ifYOwgdH5ro/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-28T14:38:56Z',
#   'Duration': 'PT16S',
#   'Views': '2014',
#   'Likes': '59',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'BSSTWseDdhI',
#   'Title': 'Glitter paper home decoration  | craftsea',
#   'Tags': ['glitter paper home decor ideas'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BSSTWseDdhI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-28T12:30:11Z',
#   'Duration': 'PT4M',
#   'Views': '113',
#   'Likes': '28',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'lIKLSKPSzu4',
#   'Title': 'Garland using roses | garland making | artificial garland',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/lIKLSKPSzu4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-27T13:20:45Z',
#   'Duration': 'PT5M59S',
#   'Views': '224',
#   'Likes': '22',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'SDJcjfVcBvg',
#   'Title': 'Tissue paper flower #shorts #viral #craftsea #papercraft',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/SDJcjfVcBvg/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-26T13:44:09Z',
#   'Duration': 'PT16S',
#   'Views': '1990',
#   'Likes': '61',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'M42QZjcB4pI',
#   'Title': 'Best out of waste | ice cream stick craft ideas |flower vase making | Craftsea',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/M42QZjcB4pI/default.jpg',
#   'Description': '#bestoutofwaste #icecreamstickcraftideas #craftsea #flowervase #flowervasemaking',
#   'Published_Date': '2023-03-26T12:30:10Z',
#   'Duration': 'PT3M56S',
#   'Views': '173',
#   'Likes': '20',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'MgPL-OUmOUM',
#   'Title': 'Satin ribbon flower garland making | #satinribbon CRAFTSEA',
#   'Tags': ['garland making using satin ribbon',
#    'garland making',
#    'garland making with satin ribbon',
#    'satin ribbon crafts',
#    'satin ribbon',
#    'garland'],
#   'Thumbnail': 'https://i.ytimg.com/vi/MgPL-OUmOUM/default.jpg',
#   'Description': '#satinribbon #garlandmaking #garland #craftsea #satinribboncrafts',
#   'Published_Date': '2023-03-25T12:48:59Z',
#   'Duration': 'PT11M19S',
#   'Views': '1335',
#   'Likes': '32',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'm0CIZMl6wEc',
#   'Title': 'Colourful art #shorts #art #craftsea #trending #viral #colours',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/m0CIZMl6wEc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-25T10:37:54Z',
#   'Duration': 'PT16S',
#   'Views': '1987',
#   'Likes': '52',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'AnKmeR86Chs',
#   'Title': 'Paper flower making #shorts #craftsea #papercraft #paperflower #viral #trending',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/AnKmeR86Chs/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-24T12:46:56Z',
#   'Duration': 'PT18S',
#   'Views': '2131',
#   'Likes': '83',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'r0wpAGHvhN0',
#   'Title': 'Wall mirror decoration at home | mirror decoration at home | diy home decor | CRAFTSEA',
#   'Tags': ['craftsea',
#    'mirror wall decoration ideas living room',
#    'mirror decoration',
#    'mirror decoration at home',
#    'mirror decoration ideas',
#    'home decor',
#    'diy home decor',
#    'home decor ideas'],
#   'Thumbnail': 'https://i.ytimg.com/vi/r0wpAGHvhN0/default.jpg',
#   'Description': '#craftsea #mirrordecoration #homedecoration #homedecor #diyhomedecor #mirrordecor',
#   'Published_Date': '2023-03-24T12:30:34Z',
#   'Duration': 'PT4M11S',
#   'Views': '186',
#   'Likes': '21',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '8wRJ7pBT7pQ',
#   'Title': 'Bookmarks making with paper #shorts #craftsea #papercraft #bookmark #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/8wRJ7pBT7pQ/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-23T13:30:37Z',
#   'Duration': 'PT16S',
#   'Views': '2675',
#   'Likes': '61',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'YFdcKYU3d24',
#   'Title': 'Garland making using fish wire | Garland making tutorial | artificial garland | CRAFTSEA',
#   'Tags': ['craftsea',
#    'garland making',
#    'garland making with fish wire',
#    'garland with fish wire',
#    'fish wire garland',
#    'garland making tutorial',
#    'artifical garland making'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YFdcKYU3d24/default.jpg',
#   'Description': '#craftsea #garlandmaking #garland #artificialgarland',
#   'Published_Date': '2023-03-23T12:47:07Z',
#   'Duration': 'PT11M13S',
#   'Views': '1226',
#   'Likes': '32',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'PeJztihQyRg',
#   'Title': 'Diwali decoration ideas  | CRAFTSEA',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/PeJztihQyRg/default.jpg',
#   'Description': 'mango leaves decoration ideas,mango leaves decoration,decoration with mango leaves,decoration ideas with mango leaves,decoration with mango leaves and flowers',
#   'Published_Date': '2023-03-21T12:30:11Z',
#   'Duration': 'PT5M13S',
#   'Views': '158',
#   'Likes': '27',
#   'Comments': '3',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '-lGLh7RJeyo',
#   'Title': 'Ganesha Chaturthi background decoration ideas #decorationideas',
#   'Tags': ['shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-lGLh7RJeyo/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-21T11:54:50Z',
#   'Duration': 'PT16S',
#   'Views': '20041',
#   'Likes': '263',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'FvG4X6F0hvU',
#   'Title': 'navaratri decoration ideas #navaratri #shorts',
#   'Tags': ['shorts', 'shorts video', 'trending shorts', 'viral'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FvG4X6F0hvU/default.jpg',
#   'Description': 'garland making using cloth',
#   'Published_Date': '2023-03-20T15:06:08Z',
#   'Duration': 'PT12S',
#   'Views': '1990',
#   'Likes': '69',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'o9nm9KsY9i8',
#   'Title': 'Ugadi decoration ideas at home | CRAFTSEA',
#   'Tags': ['ugadi decoration ideas at home',
#    'ugadi decoration',
#    'ugadi decoration ideas',
#    'ugadi',
#    'ugadi decoration ideas easy',
#    'ugadi festival decoration ideas'],
#   'Thumbnail': 'https://i.ytimg.com/vi/o9nm9KsY9i8/default.jpg',
#   'Description': '#ugadi #ugadidecoration #poojadecoration \n#craftsea #trending',
#   'Published_Date': '2023-03-20T12:30:32Z',
#   'Duration': 'PT5M49S',
#   'Views': '233',
#   'Likes': '23',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'bmcWgea26ZQ',
#   'Title': 'Decoration ideas for home | jute craft ideas | Home decoration ideas | CRAFTSEA',
#   'Tags': ['decoration ideas for home',
#    'decoration ideas',
#    'for home',
#    'home decoration ideas',
#    'home decoration ideas with jute',
#    'jute crafts',
#    'jute craft ideas',
#    'jute craft',
#    'jute rope craft ideas',
#    'jute craft ideas home decorating ideas handmade',
#    'home decoration',
#    'home decor',
#    'jute home decor',
#    'home decoration craft',
#    'decoration ideas with jute',
#    'decoration with jute',
#    'decoration with jute rope',
#    'decoration',
#    'home decoration diy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bmcWgea26ZQ/default.jpg',
#   'Description': '#homedecoration #homedecorationideas #jutecraftideas #jutecraft \n\n\ndecoration ideas for home,decoration ideas,for home,home decoration ideas,home decoration ideas with jute,jute crafts,jute craft ideas,jute craft,jute rope craft ideas,jute craft ideas home decorating ideas handmade,home decoration,home decor,jute home decor,home decoration craft,decoration ideas with jute,decoration with jute,decoration with jute rope,decoration,home decoration diy',
#   'Published_Date': '2023-03-18T12:30:30Z',
#   'Duration': 'PT6M37S',
#   'Views': '377',
#   'Likes': '20',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'e6txhrkK0AU',
#   'Title': 'flower making with paper | paper flower making | #shorts #craftsea #paperflower #flowermaking',
#   'Tags': ['paper flower making',
#    'flower making with paper',
#    'paper flower',
#    'how to make a paper flower',
#    'how to make paper flower',
#    'how to make flower with paper',
#    'how to make a flower with paper',
#    'flower craft with paper',
#    'paper flower craft',
#    'easy flower making with paper',
#    'how to make rose flower with colour paper',
#    'flower paper',
#    'shorts',
#    'ytshorts',
#    'easy paper flower'],
#   'Thumbnail': 'https://i.ytimg.com/vi/e6txhrkK0AU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-16T13:56:56Z',
#   'Duration': 'PT18S',
#   'Views': '3129',
#   'Likes': '95',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'rRojY2xBlmI',
#   'Title': 'DIY handmade Basket using waste bangles | Basket making | CRAFTSEA',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/rRojY2xBlmI/default.jpg',
#   'Description': '#craftsea #basketmaking #wastebanglereuseideas #diybasket',
#   'Published_Date': '2023-03-16T12:30:27Z',
#   'Duration': 'PT6M18S',
#   'Views': '165',
#   'Likes': '25',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'aBr7FYA_nrU',
#   'Title': 'how to make butterfly with paper easy | #shorts #papercraft #butterfly #craftsea #paperbutterflies',
#   'Tags': ['paper butterfly',
#    'butterfly paper craft',
#    'how to make butterfly with paper easy',
#    'how to make paper butterfly',
#    'paper butterfly making',
#    'butterfly making with paper',
#    'how to make a paper butterfly',
#    'paper craft butterfly',
#    'how to make butterfly with paper',
#    'butterfly craft with paper',
#    'shorts',
#    'youtube shorts',
#    'paper crafts',
#    'paper',
#    'butterfly'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aBr7FYA_nrU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-15T12:54:26Z',
#   'Duration': 'PT16S',
#   'Views': '2017',
#   'Likes': '59',
#   'Comments': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'GInyWka6x88',
#   'Title': 'crafts with paper | paper crafts | #shorts #papercraft #craftsea #origami',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/GInyWka6x88/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-14T14:26:53Z',
#   'Duration': 'PT15S',
#   'Views': '3001',
#   'Likes': '82',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'J3T6Z81y7xc',
#   'Title': 'satin ribbon flowers | #shorts #satinribbonflowers #satinribbon #craftsea',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/J3T6Z81y7xc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-13T13:00:51Z',
#   'Duration': 'PT17S',
#   'Views': '2581',
#   'Likes': '63',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'gIwU0TlIj6A',
#   'Title': 'How to make keychain holder with icecream sticks | wall hanging with icecream sticks | CRAFTSEA',
#   'Tags': ['Craftsea',
#    'wall hanging',
#    'wall hanging craft ideas',
#    'wall hanging craft ideas with icecream sticks',
#    'wall hanging craft ideas with icecream sticks easy',
#    'wall hanging craft ideas with ice stick',
#    'ice cream stick craft',
#    'craft with icecream sticks',
#    'craft with icecream sticks wall hanging',
#    'craft with icecream sticks easy',
#    'how to make craft with icecream sticks',
#    'diy keychain holder',
#    'keychain holder craft',
#    'how to make keychain holder with icecream sticks',
#    'how to make keychain holder',
#    'diy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/gIwU0TlIj6A/default.jpg',
#   'Description': '#wallhanging #keychainholder #icecreamstickcraftideas #wallhangingcraftideas #craftsea \n\nCraftsea,wall hanging,wall hanging craft ideas,wall hanging craft ideas with icecream sticks,wall hanging craft ideas with icecream sticks easy,wall hanging craft ideas with ice stick,ice cream stick craft,craft with icecream sticks,craft with icecream sticks wall hanging,craft with icecream sticks easy,how to make craft with icecream sticks,diy keychain holder,keychain holder craft,how to make keychain holder with icecream sticks,how to make keychain holder,diy',
#   'Published_Date': '2023-03-12T11:54:46Z',
#   'Duration': 'PT5M53S',
#   'Views': '141',
#   'Likes': '9',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'Ji4H4j0MDtA',
#   'Title': 'paper craft wall hanging | #shorts #papercraft #wallhanging #paperwallhanging #craftsea',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Ji4H4j0MDtA/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-11T12:42:56Z',
#   'Duration': 'PT16S',
#   'Views': '2585',
#   'Likes': '71',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'OLYNoBPQ-tM',
#   'Title': 'Decoration ideas for home | woolen craft | Home decoration ideas | CRAFTSEA',
#   'Tags': ['decoration ideas for home',
#    'decoration ideas',
#    'for home',
#    'home decoration ideas',
#    'home decoration',
#    'home decor',
#    'home decoration craft',
#    'decoration',
#    'home decoration diy',
#    'woolen craft',
#    'woolen craft ideas',
#    'woolen thread craft',
#    'woolen craft easy',
#    'craft with woolen thread',
#    'easy woolen craft',
#    'mirror decoration ideas',
#    'mirror decoration'],
#   'Thumbnail': 'https://i.ytimg.com/vi/OLYNoBPQ-tM/default.jpg',
#   'Description': '#homedecoration #homedecorationideas #woolencraft  #woolencraftidea #mirrorwork \n\n\ndecoration ideas for home,decoration ideas,for home,home decoration ideas,home decoration ideas with,home decoration,home decor,,home decoration craft,decoration,home decoration diy',
#   'Published_Date': '2023-03-11T12:30:10Z',
#   'Duration': 'PT4M52S',
#   'Views': '146',
#   'Likes': '21',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'Y3WoyEuwenI',
#   'Title': 'ice cream stick crafts #shorts #youtubeshorts #walldecor #diywalldecor #trending #viral',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Y3WoyEuwenI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-03-10T13:21:10Z',
#   'Duration': 'PT15S',
#   'Views': '2633',
#   'Likes': '48',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'pgbp67f-c4c',
#   'Title': 'Wall hanging craft ideas | ice cream stick wall hanging | CRAFTSEA',
#   'Tags': ['wall hanging craft ideas',
#    'wall hanging',
#    'wall hanging craft',
#    'paper craft wall hanging',
#    'how to make wall hanging',
#    'craft ideas wall hanging',
#    'easy wall hanging',
#    'craft with paper wall hanging',
#    'craft wall hanging',
#    'wall hanging easy',
#    'wall hanging craft ideas easy',
#    'diy wall hanging',
#    'wall hanging with icecream stick',
#    'icecream stick craft',
#    'craft with icecream stick',
#    'ice cream stick wall hanging',
#    'wall hanging ideas',
#    'ice cream stick craft ideas',
#    'ice cream stick',
#    'ice cream stick project'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pgbp67f-c4c/default.jpg',
#   'Description': '#craftsea #wallhanging #icecreamstickcraftideas #wallhangingcraftideas #walldecor \n\n\nwall hanging craft ideas,wall hanging,wall hanging craft,paper craft wall hanging,how to make wall hanging,craft ideas wall hanging,easy wall hanging,craft with paper wall hanging,craft wall hanging,wall hanging easy,wall hanging craft ideas easy,diy wall hanging,wall hanging with icecream stick,icecream stick craft,craft with icecream stick,ice cream stick wall hanging,wall hanging ideas,ice cream stick craft ideas,ice cream stick,ice cream stick project',
#   'Published_Date': '2023-03-10T12:30:22Z',
#   'Duration': 'PT4M33S',
#   'Views': '127',
#   'Likes': '24',
#   'Comments': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'hMg1wwBM4JE',
# ...
#   'Published_Date': '2021-06-28T05:22:57Z',
#   'Duration': 'PT7M39S',
#   'Views': '323',
#   'Likes': '42',
#   'Comments': '9',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'cEI6I0Q0nec',
#   'Title': 'AMAZING idea to reuse waste CD | best out of waste diy | butterfly making with old cd | craftsea',
#   'Tags': ['craftsea',
#    'craft sea',
#    'best out of waste',
#    'best out of waste cd',
#    'cd reuse ideas',
#    'cd reuse ideas in tamil',
#    'how to reuse cd for decoration',
#    'how to reuse cd discs',
#    'amazing idea to reuse waste cd',
#    'diy using old cds',
#    'diy with used cds',
#    'diy with old cds',
#    'old cd craft ideas',
#    'old cd decoration ideas',
#    'butterfly making diy',
#    'best out of waste butterfly',
#    'how to make butterfly with cd',
#    'butterfly making',
#    'waste cd diy',
#    'reuse cd ideas',
#    'cd recycling ideas',
#    'waste cd reuse ideas',
#    'old cd diys',
#    'cd'],
#   'Thumbnail': 'https://i.ytimg.com/vi/cEI6I0Q0nec/default.jpg',
#   'Description': "Amazing butterfly making using waste CD's / how to make easy butterfly/ butterfly making/ best out of waste ideas/ waste cd craft ideas / reuse old cds \n#bestoutofwaste #craftsea #reuseidea #cdcraftideas #wastematerialcraft #viral #trending \n\n\n\nkeywords:-\ncraftsea,craft sea,best out of waste,best out of waste cd,cd reuse ideas,cd reuse ideas in tamil,how to reuse cd for decoration,how to reuse cd discs,amazing idea to reuse waste cd,diy using old cds,diy with used cds,diy with old cds,old cd craft ideas,old cd decoration ideas,butterfly making diy,best out of waste butterfly,how to make butterfly with cd,butterfly making,waste cd diy,reuse cd ideas,cd recycling ideas,waste cd reuse ideas,old cd diys,cd",
#   'Published_Date': '2021-06-23T03:22:28Z',
#   'Duration': 'PT7M19S',
#   'Views': '1588',
#   'Likes': '59',
#   'Comments': '3',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'EB0maRf3VD4',
#   'Title': 'How to make a mini woolen mat | woolen mat making | table mat making',
#   'Tags': ['woolen craft ideas',
#    'woolen craft easy',
#    'woolen mat making at home',
#    'woolen mat',
#    'woolen small mat',
#    'table mat making at home',
#    'table mat making with wool',
#    'woolen table mat making',
#    'woolen table mat making at home',
#    'small mat making',
#    'woolen mini craft',
#    'mat design',
#    'mat design making',
#    'mat design for floor',
#    '5 minute woolen craft',
#    'woolen design',
#    'woolen decoration ideas',
#    'woolen craft step by step',
#    'step by step wool craft',
#    'woolen crafts for beginners',
#    'woolen craft',
#    'wool table mat'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EB0maRf3VD4/default.jpg',
#   'Description': 'Hi there, welcome to Craftsea.            \n            \nIn this channel, you can find making crafts for all occasions decoration - from the comfort of your own home!!!! We make crafts using waste/reuse materials and easily available products             \n#CRAFTSEA #woolencrafts #diyusingwoolen #diy            \n            \nFor more woolen crafts: https://youtube.com/playlist?list=PLYqlb7ZVryPXv1jhI5McuxlxYeAHek3me            \n            \nHere you can find DIYs for -            \n            \n POOJA decoration ideas at home: https://youtube.com/playlist?list=PLYqlb7ZVryPX2oqedl297x7Ov2ifKgil1            \n            \nVARALAKSHMI POOJA decoration ideas at home:  https://youtube.com/playlist?list=PLYqlb7ZVryPUCvhZn4CH23GWGTm473Hun             \n            \n DIWALI decorations at home: https://youtube.com/playlist?list=PLYqlb7ZVryPX2oqedl297x7Ov2ifKgil1            \n            \n KRISHNA JANMASHTAMI decoration ideas at home:  https://youtube.com/playlist?list=PLYqlb7ZVryPUvONdLpDzuS_jdZ-gLmg3-            \n            \n GANESHA CHATURTHI decoration ideas at home: https://youtube.com/playlist?list=PLYqlb7ZVryPVbPksFSu3s7kkBeR0uOtDf            \n            \nAnd also you can find:            \nHOME Decoration ideas: https://youtube.com/playlist?list=PLYqlb7ZVryPUpfrFx95UDxhX1irLMG22t            \n            \nSubscribe to our channel and click the bell icon to stay connected with us.            \n            \n#craftsea #varalakshmipoojadecortions #diwalidecorations #krishnajanmastamidecorations             \n#ganeshachaturthidecorations #poojadecorations #homedecoration #homedecor #diyfordecorations #craftsfordecorationideas #decorationideas #decorations            \n            \n DON’T FORGET TO SHARE, LIKE, AND SUBSCRIBE            \n KEEP SUPPORTING US…..👍👍👍            \n            \nKeywords:            \ncraftsea,woolen craft easy,woolen craft ideas,woolen craft wall hanging,woolen craft ideas easy,woolen craft ideas beautiful wall hanging,diy using woolen thread,diy wall hanging using woolen and old bangles,diy handmade wall hanging using woolen,woolen craft ideas in telugu,crochet,crochet for beginners in tamil,how to make crafts with wool,how to make crafts with woolen thread,how to make crafts with woolen,diy handmade crafts,diy handmade craft ideas,woolen crafts for home decoration,woolen crafts wall hanging,woolen thread craft,woolen thread craft wall hanging simple,woolen thread flower making,wall hanging with wool,wall hanging with woolen thread,wall hanging using woolen thread,wall hanging using wool,wall hanging using woolen,woolen,woolen diy,woolen diy crafts,easy woolen craft,crafts with woolen thread easy,crafts with woolen thread easy wall hanging,5 minute crafts with woolen thread easy,easy woolen craft ideas,craft ideas with wool diy home decor easy woolen flower,woolen crafts for beginners,easy woolen crafts,woolen flower making wall hanging,woolen flower making door hanging,woolen flower making easy,woolen flower making,woolen flower design,woolen bag new design,woolen bag new design easy,woolen bag making step by step,woolen birds wall hanging,woolen bird craft,woolen birds easy,how to make bird using woolen thread,how to make bird using wool Hi there, welcome to craftsea.\n This channel is all about creating crafts easily - from the comfort of your own home!!!!\n\n\nHow to make a mini woolen mat | woolen design for beginners| easy woolen crafts for beginners step by step  | woolen mat making | table mat making \n\n\nMATERIALS NEEDED:\n👉 Woolen \n👉Crochet needle\n\n\nLINK FOR MATERIALS:\n👉woolen thread: https://amzn.to/3gwFcgW \n👉under 500: https://amzn.to/3gnjfCc\n👉6 colors combo under 250: https://amzn.to/3xyxvOj\n👉crochet needle: https://amzn.to/3iSX4Wf\n👉crochet needle set: https://amzn.to/3wuj4e0\n\n\nSTEPS FOR 1ST MAT:\nSTEP-1: 5 ch, link\nSTEP-2:  3 long ch, 2 ch , 3 l.ch, 2 ch (4 times)\nSTEP-3: 3 long ch, 1ch  (8 times)\nSTEP-4: 3 long ch, 1 ch, 6 long ch,1 ch (8 ...
#   'Published_Date': '2021-06-22T04:28:04Z',
#   'Duration': 'PT10M11S',
#   'Views': '158',
#   'Likes': '32',
#   'Comments': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'V912Jdb0Qoc',
#   'Title': 'How to make super easy paper flower | tissue paper flowers | CRAFTSEA',
#   'Tags': ['craftsea',
#    'paper flower',
#    'paper flowers',
#    'tissue paper',
#    'tissue paper flowers',
#    'easy paper flowers',
#    'paper flower craft simple',
#    'paper flower craft ideas',
#    'paper flower craft easy',
#    'paper flower making',
#    'paper flowers easy',
#    'paper flower craft',
#    'tissue paper flower making',
#    'tissue paper flowers decorations',
#    'How to make super easy paper flower',
#    'easy flower making with paper',
#    'easy flower making',
#    'easy flower making with paper for kids',
#    'diy flower making using paper',
#    'tissue paper flower craft'],
#   'Thumbnail': 'https://i.ytimg.com/vi/V912Jdb0Qoc/default.jpg',
#   'Description': 'How to make easy, simple and creative paper flowers using tissue paper | how to make tissue paper flowers easily \n\nHi there, welcome to craftsea.\n This channel is all about creating crafts easily - from the comfort of your own home!!!!\n\nMATERIALS NEEDED:\n 👉 Tissue paper \n 👉 Glue \n 👉  paint\n 👉  green tape\n 👉  flower making wire\n\nLINK FOR MATERIALS: \n  👉 Tissue paper: https://amzn.to/3cXSAJR\n 👉 Glue : https://amzn.to/3gL6W1r\n  👉 Gluegun : https://amzn.to/3xBfE9o\n 👉  paint: https://amzn.to/3gNhtJw\n 👉  green tape: https://amzn.to/3cZfSzg\n 👉  flower making wire coated with green tape: https://amzn.to/3gKTevC\n\n#craftsea #paperflowermaking #paperflowers #tissuepaperflower #diypaperflower\n\n\nSUBSCRIBE FOR MORE VIDEOS: https://www.youtube.com/c/Craftsea\n\nMY OTHER VIDEOS:\n         #BESTOUTOFWASTE:\n  BEST OUT OF WASTE-FLOWER VASE MAKING: https://youtu.be/2qgIe6YKccY\n  WASTE BANGEL REUSE IDEA| THORAN | WALL HANGING: https://youtu.be/6zVyBRCcZdQ\n  BUTTERFLY MAKING USING WASTE CD’S: https://youtu.be/cEI6I0Q0nec\n  CELING LIGHT |DIY LIGHT| JUMHER: https://youtu.be/-paHEJUfSAE\n\n THANKS FOR WATCHING OUR VIEDO \n DON’T FORGET TO SHARE,LIKE AND SUBSCRIBE\n KEEP SUPPORTING US…..👍👍👍',
#   'Published_Date': '2021-06-21T03:14:04Z',
#   'Duration': 'PT10M3S',
#   'Views': '360',
#   'Likes': '42',
#   'Comments': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': '2qgIe6YKccY',
#   'Title': 'Cardboard flower vase making | making flower vase | woolen flower vase making | craftsea',
#   'Tags': ['flower vase making',
#    'cardboard flower vase',
#    'flower vase making with wool',
#    'cardboard flower vase making',
#    'cardboard flower vase easy',
#    'cardboard flower pot',
#    'flower vase with cardboard',
#    'flower vase with cardboard box',
#    'how to make big flower vase with cardboard',
#    'cardboard tube flower vase',
#    'how to make flower vase',
#    'how to make flower vase at home',
#    'flower vase making with cardboard',
#    'making flower vase',
#    'woolen flower vase making',
#    'flower vase craft with cardboard',
#    'flower vase',
#    'cardboard'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2qgIe6YKccY/default.jpg',
#   'Description': '#craftsea #flowervase #flowervasemaking #cardboardcraft \n\nflower vase making,cardboard flower vase,flower vase making with wool,cardboard flower vase making,cardboard flower vase easy,cardboard flower pot,flower vase with cardboard,flower vase with cardboard box,how to make big flower vase with cardboard,cardboard tube flower vase,how to make flower vase,how to make flower vase at home,flower vase making with cardboard,making flower vase,woolen flower vase making,flower vase craft with cardboard,flower vase,cardboard',
#   'Published_Date': '2021-06-18T04:42:32Z',
#   'Duration': 'PT3M39S',
#   'Views': '362',
#   'Likes': '50',
#   'Comments': '11',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'wvZuxzUTzeI',
#   'Title': 'Woolen purse making | purse making with wool | easy woolen crafts |  CRAFTSEA',
#   'Tags': ['Purse making with wool',
#    'how to make woolen purse',
#    'how to make purse with woolen thread',
#    'woolen purse making for beginners',
#    'woolen purse making easy',
#    'woolen purse making',
#    'woolen purse',
#    'woolen',
#    'woolen purse design',
#    'woolen purse new design',
#    'woolen purse making at',
#    'how to make woolen purse at home',
#    'purse making with woolen',
#    'purse making with wool',
#    'woolen craft'],
#   'Thumbnail': 'https://i.ytimg.com/vi/wvZuxzUTzeI/default.jpg',
#   'Description': '#craftsea #woolencraft #woolencraftidea \n\nPurse making with wool, how to make woolen purse, how to make purse with woolen thread, woolen purse making for beginners, woolen purse making easy, woolen purse making, woolen purse, woolen, woolen purse design, woolen purse new design, woolen purse making at, how to make woolen purse at home, purse making with woolen, purse making with wool, woolen craft',
#   'Published_Date': '2021-06-16T16:25:44Z',
#   'Duration': 'PT14M45S',
#   'Views': '390',
#   'Likes': '46',
#   'Comments': '8',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'nBWNgl9RHLE',
#   'Title': 'Woolen flower making | woolen flower | woolen rose flower making #woolenflower  | CRAFTSEA',
#   'Tags': ['woolen flower making',
#    'woolen flower making easy',
#    'woolen rose flower making',
#    'how to make woolen flower',
#    'woolen flower design',
#    'woolen flower design step by step',
#    'woolen rose flower making easy',
#    'easy woolen flower making ideas',
#    'woolen flower',
#    'woolen flower making with crochet',
#    'woolen thread flower making',
#    'woolen thread flower',
#    'woolen flower craft',
#    'woolen flower making at home',
#    'easy woolen craft ideas'],
#   'Thumbnail': 'https://i.ytimg.com/vi/nBWNgl9RHLE/default.jpg',
#   'Description': '#woolenflower #woolenflowermaking #craftsea \nwoolen flower making,woolen flower making easy,woolen rose flower making,how to make woolen flower,woolen flower design,woolen flower design step by step,woolen rose flower making easy,easy woolen flower making ideas,woolen flower,woolen flower making with crochet,woolen thread flower making,woolen thread flower,woolen flower craft,woolen flower making at home,easy woolen craft ideas',
#   'Published_Date': '2021-06-15T13:09:42Z',
#   'Duration': 'PT7M57S',
#   'Views': '414',
#   'Likes': '52',
#   'Comments': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'},
#  {'Channel_Name': 'Craftsea',
#   'Channel_Id': 'UCEMquPOusz7h58nimU7P0uA',
#   'Video_Id': 'XxDmNbCWUD0',
#   'Title': 'Woolen doll making at home | woolen doll new design | #woolencraft #woolendoll  | CRAFTSEA',
#   'Tags': ['woolen doll making at home',
#    'woolen doll making crochet',
#    'woolen doll making at home easy',
#    'woolen doll new design',
#    'woolen doll new design easy',
#    'woolen craft doll',
#    'woolen craft doll design',
#    'how to make woolen doll',
#    'woolen doll making',
#    'woolen doll dress making',
#    'woolen doll craft',
#    'woolen doll',
#    'doll woolen',
#    'how to make woolen doll dress',
#    'how to make woolen doll at home',
#    'how to make doll using woolen thread',
#    'doll making using woolen thread',
#    'woolen crafts',
#    'craftsea',
#    'doll making',
#    'woolen'],
#   'Thumbnail': 'https://i.ytimg.com/vi/XxDmNbCWUD0/default.jpg',
#   'Description': '#craftsea #woolendoll #woolencraft #woolencraftidea \nwoolen doll making at home, woolen doll making crochet, woolen doll making at home easy, woolen doll new design, woolen doll new design easy, woolen craft doll, woolen craft doll design, how to make a woolen doll, woolen doll making, woolen doll dress making, woolen doll craft, woolen doll, doll woolen, how to make woolen doll dress, how to make a woolen doll at home, how to make doll using woolen thread, doll making using woolen thread, woolen crafts, craftsea, doll making, woolen',
#   'Published_Date': '2021-06-14T16:53:55Z',
#   'Duration': 'PT11M8S',
#   'Views': '819',
#   'Likes': '66',
#   'Comments': '28',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Details': 'false'}]

# %%
#get comment information
def get_command_info(v_i):
    comment_data=[]
    try:
        for video_id in v_i:
            request = youtube.commentThreads().list(
                    part='snippet',
                    videoId=video_id,
                    maxResults=50
                )
            response=request.execute()
            for item in response['items']:
                data=dict(comment_id=item['snippet']['topLevelComment']['id'],
                        Video_id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt']
                        )
                comment_data.append(data)
    except:
        pass
    return comment_data

# %%
comment_details=get_command_info(Video_id)

# %%
len(comment_details)
# Out:
# 182

# %%
#get playlist details   
def get_playlist_details(channel_id):
    next_page_token=None
    all_data=[]
    while True:
        request=youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response=request.execute()

        for item in response['items']:
            data=dict(Playlist_ID=item['id'],
                    Title=item['snippet']['title'],
                    Channel_Id=item['snippet']['channelId'],
                    Channel_Name=item['snippet']['channelTitle'],
                    Published_At=item['snippet']['publishedAt'],
                    Video_count=item['contentDetails']['itemCount']

            )
            all_data.append(data)
        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return all_data

# %%
Playlist_details=get_playlist_details('UCunaYVFwuXJj2Dg3ekXqlBQ')

# %%
#GUDIYATTAM 360 -   UCunaYVFwuXJj2Dg3ekXqlBQ
# CRAFTSEA      -   UCEMquPOusz7h58nimU7P0uA
# ROBIN SHARMA  -   UC6oh54zIYKyW6hgBiZzLLsA

# %%
#upload to mongodb
client=pymongo.MongoClient("mongodb+srv://Pavithra:Tamilarasan@pavithra.fmljuh2.mongodb.net/?retryWrites=true&w=majority")
db=client['youtube_data']

# %%
def channel_details(channel_id):
   ch_details=get_channel_info(channel_id)
   pl_details=get_playlist_details(channel_id)
   v_ids=get_video_ids(channel_id)
   vi_details=get_video_details(v_ids)
   com_details=get_command_info(v_ids)

   collec1=db['channel_details']
   collec1.insert_one({'channel_information':ch_details,'playlist_information':pl_details,
                       'video_information':vi_details,'command_information':com_details})
    
   return "upload successfully"

# %%
#GUDIYATTAM 360 -   UCunaYVFwuXJj2Dg3ekXqlBQ
# CRAFTSEA      -   UCEMquPOusz7h58nimU7P0uA
insert=channel_details('UC6oh54zIYKyW6hgBiZzLLsA')

# %%
#table creation for channel playlist videos comments
def get_channel_tables():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='1527',
                        database='youtube_data',
                        port='5432')
    cursor=mydb.cursor()
    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(channel_Name varchar(100),
                                                            channel_id varchar(80) primary key,
                                                            subsribers bigint,
                                                            views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_ID varchar (80))'''
        cursor.execute(create_query)
        mydb.commit()
    except:
        print("channels already created")


    ch_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for ch_data in collec1.find({},{'_id':0,'channel_information':1}):
        ch_list.append(ch_data['channel_information'])
    df=pd.DataFrame(ch_list)

    for index,row in df.iterrows():
        insert_query='''insert into channels(channel_Name ,
                                            channel_id,
                                            subsribers,
                                            views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_ID)
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['channel_Name'],
                row['channel_id'],
                row['subsribers'],
                row['views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_ID'])

        try:
            cursor.execute(insert_query,values)
            mydb.commit()
        except:
            print("channel values are already inserted")

# %%
def get_playlist_table():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='1527',
                        database='youtube_data',
                        port='5432')
    cursor=mydb.cursor()
    drop_query='''drop table if exists playlist'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists playlist(Playlist_ID varchar(100) primary key,
                                                        Title varchar(100),
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        Published_At timestamp,
                                                        Video_count int)'''

    cursor.execute(create_query)
    mydb.commit()

    pl_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for pl_data in collec1.find({},{'_id':0,'playlist_information':1}):
        for i in range (len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])
    df1=pd.DataFrame(pl_list)

        
    for index,row in df1.iterrows():
        insert_query='''insert into playlist(Playlist_ID ,
                                        Title, 
                                        Channel_Id ,
                                        Channel_Name, 
                                        Published_At ,
                                        Video_count )
                                        values(%s,%s,%s,%s,%s,%s)'''
        values=(row['Playlist_ID'],
            row['Title'],
            row['Channel_Id'],
            row['Channel_Name'],
            row['Published_At'],
            row['Video_count'],
            )

        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("playlist values are already inserted")

# %%
def get_video_table():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='1527',
                        database='youtube_data',
                        port='5432')
    cursor=mydb.cursor()
    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar (100),
                                                    Video_Id varchar(30),
                                                    Title varchar(100),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favourite_Count int,
                                                    Definition varchar(20),
                                                    Caption_Details varchar(20))'''

    cursor.execute(create_query)
    mydb.commit()

    vi_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for vi_data in collec1.find({},{'_id':0,'video_information':1}):
        for i in range (len(vi_data['video_information'])):
            vi_list.append(vi_data['video_information'][i])
    df2=pd.DataFrame(vi_list)

        
    for index,row in df2.iterrows():
        insert_query='''insert into videos(Channel_Name,
                                            Channel_Id,
                                            Video_Id,
                                            Title,
                                            Tags,
                                            Thumbnail,
                                            Description,
                                            Published_Date,
                                            Duration,
                                            Views,
                                            Likes,
                                            Comments,
                                            Favourite_Count,
                                            Definition,
                                            Caption_Details)
                                        values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
            row['Channel_Id'],
            row['Video_Id'],
            row['Title'],
            row['Tags'],
            row['Thumbnail'],
            row['Description'],
            row['Published_Date'],
            row['Duration'],
            row['Views'],
            row['Likes'],
            row['Comments'],
            row['Favourite_Count'],
            row['Definition'],
            row['Caption_Details']

            )

        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("playlist values are already inserted")

# %%
def get_comment_table():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='1527',
                        database='youtube_data',
                        port='5432')
    cursor=mydb.cursor()
    drop_query='''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists comments(comment_id varchar(100) primary key,
                                                        Video_id varchar(50),
                                                        Comment_text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp)'''

    cursor.execute(create_query)
    mydb.commit()

    comm_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for comm_data in collec1.find({},{'_id':0,'command_information':1}):
        for i in range (len(comm_data['command_information'])):
            comm_list.append(comm_data['command_information'][i])
    df3=pd.DataFrame(comm_list)

    for index,row in df3.iterrows():
        insert_query='''insert into comments(comment_id,
                                            Video_id,
                                            Comment_text, 
                                            Comment_Author,
                                            Comment_Published)
                                        values(%s,%s,%s,%s,%s)'''
        values=(row['comment_id'],
            row['Video_id'],
            row['Comment_text'],
            row['Comment_Author'],
            row['Comment_Published']
            )
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def tables():
    get_channel_tables()
    get_playlist_table()
    get_video_table()
    get_comment_table()

    return "tables are created successfully"

# %%
Tables=tables()

# %%
def show_channel_tables():
    ch_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for ch_data in collec1.find({},{'_id':0,'channel_information':1}):
        ch_list.append(ch_data['channel_information'])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlist_table():
    pl_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for pl_data in collec1.find({},{'_id':0,'playlist_information':1}):
        for i in range (len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_video_table():
    vi_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for vi_data in collec1.find({},{'_id':0,'video_information':1}):
        for i in range (len(vi_data['video_information'])):
            vi_list.append(vi_data['video_information'][i])
    df2=st.dataframe(vi_list)
    
    return df2

# %%
def show_comment_table():
    comm_list=[]
    db=client['youtube_data']
    collec1=db['channel_details']
    for comm_data in collec1.find({},{'_id':0,'command_information':1}):
        for i in range (len(comm_data['command_information'])):
            comm_list.append(comm_data['command_information'][i])
    df3=st.dataframe(comm_list)
    
    return df3

# %%
# streamlit part

with st.sidebar:
    st.title(":purple[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("SKILLS ")
    st.caption("python scripting")
    st.caption("data collection")
    st.caption("MongoDB")
    st.caption("API integration")
    st.caption("Data management using MongoDB and SQL")
channel_id=st.text_input("Enter the channel ID")

if st.button("collect and store data"):
    ch_ids=[]
    db=client["youtube_data"]
    collec1=db["channel_details"]
    for ch_data in collec1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["channel_Id"])
    if channel_id in ch_ids:
        st.success("Already exists")
    else:
        insert= channel_details(channel_id)
        st.success(insert)
if st.button("MIGRATE TO SQL"):
    Table=tables()
    st.success(Table)

show_table=st.radio("SELECT THE VIEW FOR BELOW TABLES",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
    show_channel_tables()
elif show_table=="PLAYLISTS":
    show_playlist_table()
elif show_table=="VIDEOS":
    show_video_table()
elif show_table=="COMMENTS":
    show_comment_table()

# %%
#SQL Connection
mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='1527',
                        database='youtube_data',
                        port='5432')
cursor=mydb.cursor()

question=st.selectbox("select your question",
                      ("1.What are the names of all the videos and their corresponding channels?",
                        "2.Which channels have the most number of videos, and how many videos do they have?",
                        "3. What are the top 10 most viewed videos and their respective channels?",
                        "4. How many comments were made on each video, and what are their corresponding video names?",
                        "5.Which videos have the highest number of likes, and what are their corresponding channel names?",
                        "6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
                        "7. What is the total number of views for each channel, and what are their corresponding channel names?",
                        "8. What are the names of all the channels that have published videos in the year 2022?",
                        "9. What is the average duration of all videos in each channel, and what are their corresponding channel names?",
                        "10. Which videos have the highest number of comments, and what are their corresponding channel names?"))

if question=="1.What are the names of all the videos and their corresponding channels?":
    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["VIDEO NAMES","CHANNEL NAMES"])
    st.write(df)
elif question=="2.Which channels have the most number of videos, and how many videos do they have?":
    query2='''select channel_name as channelnames, total_videos as no_videos from channels
                order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2,columns=["CHANNEL NAMES","NO OF VIDEOS"])
    st.write(df2)

elif question=="3. What are the top 10 most viewed videos and their respective channels?":
    query3='''select views as views,channel_name as channelname, title as videotitle from videos
                where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["VIEWS","CHANNEL NAME","VIDEO TITLE"])
    st.write(df3)

elif question=="4. How many comments were made on each video, and what are their corresponding video names?":
   
    query4='''select comments as no_commands,title  as videotitle from videos
                where comments is not null '''
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["NO OF COMMANDS","VIDEO TITLE"])
    st.write(df4)

elif question=="5.Which videos have the highest number of likes, and what are their corresponding channel names?":
    query5='''select title  as videotitle, channel_name as channelnames, likes as likecount from videos
                where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["VIDEO TITLE","CHANNEL NAME","LIKE COUNT"])
    st.write(df5)

elif question=="6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?":
   
    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["LIKE COUNT","VIDEO TITLE"])
    st.write(df6)

elif question=="7. What is the total number of views for each channel, and what are their corresponding channel names?":
   
    query7='''select channel_name as channelnames,views as viewcount from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["CHANNEL NAME","TOTAL VIEWS"])
    st.write(df7)

elif question=="8. What are the names of all the channels that have published videos in the year 2022?":
    query8='''select title as video_title,published_date as videorelease,channel_name as channelname from videos
                where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["VIDEO TITLE","PUBLISHED DATE","CHANNEL NAME"])
    st.write(df8)

elif question=="9. What is the average duration of all videos in each channel, and what are their corresponding channel names?":
    query9='''select title as videotitle, channel_name as channelname, comments as comments from videos 
                where comments is not null order by comments desc'''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["CHANNEL NAME", "AVERAGE DURATION"])
    T9=[]
    for index,row in df9.iterrows():
        channel_title=row["CHANNEL NAME"]
        averageduration = row["AVERAGE DURATION"]
        averageduration_str=str(averageduration)
        T9.append(dict(CHANNELNAME=channel_title,AVERAGEDURATION=averageduration_str))
    df1=pd.DataFrame(T9)
    st.write(df1)
elif question=="10. Which videos have the highest number of comments, and what are their corresponding channel names?":

    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos
                where comments is not null order by comments desc '''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["VIDEO TITLE","CHANNEL NAME","COMMENTS"])
    st.write(df10)

# %%
mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='1527',
                        database='youtube_data',
                        port='5432')
cursor=mydb.cursor()
query10='''select title as videotitle,channel_name as channelname,comments as comments from videos
            where comments is not null order by comments desc '''
cursor.execute(query10)
mydb.commit()
t10=cursor.fetchall()
df10=pd.DataFrame(t10,columns=["VIDEO TITLE","CHANNEL NAME","COMMENTS"])
st.write(df10)

# %%
df10
# Out:
#                                             VIDEO TITLE    CHANNEL NAME  \
# 0     Australia fire | #Australia_fire | Pray for Au...  Gudiyattam 360
# 1      6 Things I Wish I'd Learned At 20 | Robin Sharma    Robin Sharma
# 2                   How to Wake Up Early | Robin Sharma    Robin Sharma
# 3     A Method To x100 Your Productivity | Robin Sharma    Robin Sharma
# 4      How to Be Comfortable Being Alone | Robin Sharma    Robin Sharma
# ...                                                 ...             ...
# 1097  Envelope making with paper | paper crafts #sho...        Craftsea
# 1098  #shorts #papercraft #craftsea #trending #paper...        Craftsea
# 1099  peacock making using foam sheet #shorts #diycr...        Craftsea
# 1100                      #shorts #craftsea #ipl #viral        Craftsea
# 1101  paper crafts #shorts #trending #craftsea #pape...        Craftsea
#
#       COMMENTS
# 0         8297
# 1         2398
# 2         1747
# 3         1245
# 4         1045
# ...        ...
# 1097         0
# 1098         0
# 1099         0
# 1100         0
# 1101         0
#
# [1102 rows x 3 columns]
